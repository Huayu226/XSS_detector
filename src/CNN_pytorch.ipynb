# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
# 確認是否有 GPU 可以使用
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# 假設您的資料在 'xss_data.xlsx'，第一個 column 是 XSS 負載，第二個 column 是標籤
df = pd.read_csv('../res/model/all.csv', header=None)
xss_payloads = df[0].tolist() # 第一欄為 XSS 負載
labels = df[1].tolist()       # 第二欄為標籤（0 或 1）

def preprocess_payload(payload):
    def replace_url(text):
        text = re.sub(r'http[s]?://[^\s"<>]+', 'http://u', text)
        text = re.sub(r'ftp://[^\s"<>]+', 'http://u', text)
        text = re.sub(r'mailto:[^\s"<>]+', 'http://u', text)
        text = re.sub(r'file://[^\s"<>]+', 'http://u', text)
        text = re.sub(r'tel:[^\s"<>]+', 'http://u', text)
        text = re.sub(r'data:[^\s"<>]+', 'http://u', text)
        text = re.sub(r'(href|src|action|formaction|background)=[\'"][^\s"<>]+[\'"]', r'\1="http://u"', text)
        text = re.sub(r'srcset="([^"]+)"', lambda match: 'srcset="r"', text)
    
        return text

    # 替換數字為單個 0
    def replace_numbers(text):
        return re.sub(r'\d+', '0', text)  # 使用 \d+ 確保每組數字只替換為一個 0

    # 保留 HTML 標籤並處理內容
    def process_tag(match):
        tag_content = match.group(0)
        # 替換標籤內的 URL
        tag_content = replace_url(tag_content)
        # 替換標籤內的數字
        tag_content = replace_numbers(tag_content)
        return tag_content

    # 使用正則表達式匹配 HTML 標籤並處理
    processed_payload = re.sub(r'<[^>]+>', process_tag, payload)
        
    # 處理標籤外的數字和 URL
    processed_payload = replace_url(processed_payload)
    processed_payload = replace_numbers(processed_payload)
        
    return processed_payload

def custom_tokenize(text):
    # 定義正則表達式規則
    pattern = r'''(?x)                         # 開啟 verbose 模式，讓正則表達式更易讀
        "[^"]+"                                # 匹配雙引號內的內容
        | '[^']+'                              # 匹配單引號內的內容
        | http://\w+                           # 匹配 http:// 開頭的 URL
        | <\w+>                                # 匹配開啟的 HTML 標籤 <tag>
        | </\w+>                               # 匹配關閉的 HTML 標籤 </tag>
        | \w+=                                 # 匹配像 name=value 這樣的結構
        | [\w\.]+                              # 匹配普通單詞（字母、數字、下劃線或點）
        | [\s]+                                # 匹配空白字符
        | [^\w\s<>]+                           # 匹配非字母數字空白和非標籤的其他字符
    '''
        
    # 使用正則表達式分詞
    tokens = re.findall(pattern, text)
        
    # 清除多餘的空格字符
    tokens = [token.strip() for token in tokens if token.strip()]
        
    return tokens

# 對所有 XSS 負載進行預處理
processed_payloads = [preprocess_payload(payload) for payload in xss_payloads]

# 分詞
tokens = [custom_tokenize(text) for text in processed_payloads]

# %%
# 計算 TF-IDF 並篩選前 3000 詞彙
vectorizer = TfidfVectorizer(max_features=3000)  # 選擇前 3000 個高 TF-IDF 的詞
tfidf_matrix = vectorizer.fit_transform([' '.join(tokens_list) for tokens_list in tokens])
selected_words = vectorizer.get_feature_names_out()

# 篩選詞彙表，更新 tokens
tered_tokensfil = [
    [token if token in selected_words else 'UNK' for token in tokens_list] 
    for tokens_list in tokens
]

# %%
# 使用 Word2Vec 訓練詞向量模型 embedding size 設定為 128
model = Word2Vec(tered_tokensfil, vector_size=128, window=2, min_count=10, sg=1)  # sg=1 表示使用 Skip-gram 模型

# 測試模型：查看某些詞的詞向量
#print(model.wv['</sup>'])

print(model.wv.most_similar('alert'))

# 將前 3000 個詞跟對應向量寫入 res/TFIDF_top3000.txt
with open('../res/TFIDF_top3000.txt', 'w', encoding='utf-8') as f1, \
     open('../res/model_word.txt', 'w', encoding='utf-8') as f2:
    for word in selected_words:
        f1.write(word + '\n')
        if word in model.wv:
            f2.write(word + ' ')
# Out:
# [('test', 0.8620825409889221), ('eval', 0.8140711188316345), ('autofocus', 0.7931320667266846), ('td', 0.7359055876731873), ('contenteditable', 0.7319327592849731), ('input', 0.7159417271614075), ('th', 0.7099950909614563), ('color', 0.7060911059379578), ('me', 0.6864098906517029), ('content', 0.6757678389549255)]

# %%
# 提取所有詞彙及其對應的詞向量
words = list(model.wv.index_to_key)  # 取得所有詞彙
word_vectors = np.array([model.wv[word] for word in words])  # 取得每個詞的詞向量

# 使用 t-SNE 進行降維
tsne = TSNE(n_components=2, random_state=42)  # 降維到 2 維
reduced_vectors = tsne.fit_transform(word_vectors)

# 可視化
plt.figure(figsize=(10, 10))
plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], alpha=0.5)

# 顯示每個詞的位置
for i, word in enumerate(words):
    plt.annotate(word, (reduced_vectors[i, 0], reduced_vectors[i, 1]), fontsize=8)

plt.title('t-SNE Visualization of Word2Vec Vectors')
plt.show()

# %%
def tokens_to_vectors(tered_tokensfil, model, max_sequence_length=100):
    vectors = []
    
    for token in tered_tokensfil:
        if token in model.wv:
            vectors.append(torch.tensor(model.wv[token], dtype=torch.float32))  # 轉為 PyTorch Tensor
        else:
            vectors.append(torch.zeros(model.vector_size, dtype=torch.float32))  # 未知詞補零

    vectors = torch.stack(vectors) if vectors else torch.zeros((0, model.vector_size), dtype=torch.float32)  

    # 進行 padding 或截取，確保 shape = (max_sequence_length, embedding_dim)
    if vectors.shape[0] < max_sequence_length:
        pad_size = max_sequence_length - vectors.shape[0]
        padding_tensor = torch.zeros((pad_size, model.vector_size), dtype=torch.float32)
        vectors = torch.cat([vectors, padding_tensor], dim=0)
    else:
        vectors = vectors[:max_sequence_length]  # 超過 max_sequence_length 則截斷

    return vectors

# 轉換所有 tokens
xss_vectors = [tokens_to_vectors(token_list, model) for token_list in tokens]

# 堆疊成 batch
xss_vectors_padded = torch.stack(xss_vectors)  # (batch_size, max_sequence_length, embedding_dim)

print(xss_vectors_padded.shape)  # (batch_size, 100, 128)
# Out:
# torch.Size([11352, 100, 128])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class XSSClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, max_seq_len):
        super(XSSClassifier, self).__init__()
        
        # CNN 層
        self.conv1 = nn.Conv1d(in_channels=input_dim, out_channels=6, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(in_channels=input_dim, out_channels=4, kernel_size=3, padding=1)
        self.conv3 = nn.Conv1d(in_channels=input_dim, out_channels=2, kernel_size=3, padding=1)
        
        # BiLSTM 層
        self.lstm = nn.LSTM(input_size=12, hidden_size=64, batch_first=True, bidirectional=True)
        
        # Self-Attention 層
        self.attention = nn.Linear(128, 1)
        
        # MaxPooling & UpSampling
        self.maxpool = nn.MaxPool1d(kernel_size=2)
        self.upsample = nn.Upsample(scale_factor=2, mode='nearest')
        
        # Fully Connected Layers
        self.fc1 = nn.Linear(140 * max_seq_len, 128)
        self.fc2 = nn.Linear(128, output_dim)
        self.dropout = nn.Dropout(0.5)

    def attention_layer(self, lstm_out):
        attn_scores = torch.tanh(self.attention(lstm_out))  # (batch, seq_len, 1)
        attn_weights = torch.softmax(attn_scores, dim=1)  # 計算權重
        attn_out = lstm_out * attn_weights  # 加權輸出
        return attn_out
 
    def forward(self, x):
        # 調整維度 (batch, seq_len, embedding_dim) → (batch, embedding_dim, seq_len)
        x = x.permute(0, 2, 1)
        
        # CNN
        conv1_out = F.relu(self.conv1(x))
        conv2_out = F.relu(self.conv2(x))
        conv3_out = F.relu(self.conv3(x))
        
        # 串接 CNN 特徵
        conv_out = torch.cat([conv1_out, conv2_out, conv3_out], dim=1)  # (batch, 12, seq_len)
        
        # 調整維度以適應 LSTM (batch, seq_len, 12)
        conv_out = conv_out.permute(0, 2, 1)
        
        # BiLSTM
        lstm_out, _ = self.lstm(conv_out)
        
        # Self-Attention
        attn_out = self.attention_layer(lstm_out)
        
        # MaxPooling + UpSampling
        pooled_out = self.maxpool(attn_out.permute(0, 2, 1))  # 變成 (batch, channels, seq_len//2)
        upsampled_out = self.upsample(pooled_out)  # 放大回原本大小 (batch, channels, seq_len)
        
        # 特徵融合
        final_features = torch.cat([conv_out, upsampled_out.permute(0, 2, 1)], dim=-1)  # (batch, seq_len, 128)
        
        # 展平成全連接層輸入
        flattened = final_features.view(final_features.size(0), -1)
        
        # Dropout + 全連接層
        fc1_out = F.relu(self.fc1(flattened))
        fc1_out = self.dropout(fc1_out)
        output = self.fc2(fc1_out)

        return output

# %%
#匯入、固定亂數、準備資料張量
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np, random, torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn.functional as F

def set_seed(seed=42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)

set_seed(42)

# X: 來自你前面已完成的向量化結果
#    xss_vectors_padded shape = (N, 100, 128)
X = xss_vectors_padded
# y: 使用整數標籤 0/1（不要 one-hot）
y = torch.tensor(labels).long()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
#訓練/驗證輔助函式（沿用你原本超參）
def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        out = model(xb)
        loss = criterion(out, yb)
        loss.backward()
        optimizer.step()
        loss_sum += loss.item() * xb.size(0)
        pred = out.argmax(dim=1)
        correct += (pred == yb).sum().item()
        total += xb.size(0)
    return loss_sum/total, correct/total

@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    total, correct, loss_sum = 0, 0, 0.0
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        out = model(xb)
        loss = criterion(out, yb)
        loss_sum += loss.item() * xb.size(0)
        pred = out.argmax(dim=1)
        correct += (pred == yb).sum().item()
        total += xb.size(0)
    return loss_sum/total, correct/total

@torch.no_grad()
def test_metrics(model, loader, device):
    """回傳整體 accuracy 與測試集中 label=1 被判成 0 的比例（bypass rate）"""
    model.eval()
    all_preds, all_true = [], []
    for xb, yb in loader:
        xb = xb.to(device)
        out = model(xb)
        all_preds.append(out.argmax(dim=1).cpu())
        all_true.append(yb)
    all_preds = torch.cat(all_preds)
    all_true  = torch.cat(all_true)

    acc = (all_preds == all_true).float().mean().item()
    mask_mal = (all_true == 1)
    mal_total = int(mask_mal.sum().item())
    if mal_total > 0:
        bypass = int(((all_preds == 0) & mask_mal).sum().item())
        bypass_rate = bypass / mal_total
    else:
        bypass_rate = float('nan')
    return acc, bypass_rate, mal_total

# %%
# 五折交叉訓練與測試
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

num_epochs = 100
early_stopping_patience = 10
batch_size = 12

results = []
fold_id = 1

for train_idx, test_idx in kf.split(np.zeros(len(y)), y.numpy()):
    print(f"\n========== Fold {fold_id}/5 ==========")

    # 每折重新初始化模型與最佳狀態
    model = XSSClassifier(input_dim=128, hidden_dim=64, output_dim=2, max_seq_len=100).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, min_lr=1e-6)

    X_train_all, X_test = X[train_idx], X[test_idx]
    y_train_all, y_test = y[train_idx], y[test_idx]

    # 由訓練集再切 10% 做驗證（分層）
    X_tr, X_val, y_tr, y_val = train_test_split(
        X_train_all, y_train_all, test_size=0.1, random_state=42, stratify=y_train_all.cpu()
    )

    train_loader = DataLoader(TensorDataset(X_tr,  y_tr),  batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(TensorDataset(X_val, y_val), batch_size=batch_size, shuffle=False)
    test_loader  = DataLoader(TensorDataset(X_test, y_test), batch_size=batch_size, shuffle=False)

    best_val, patience = float('inf'), 0

    for ep in range(num_epochs):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc = evaluate(model, val_loader, criterion, device)
        scheduler.step(val_loss)
        print(f"Fold {fold_id} | Epoch {ep+1:03d}  train_loss={tr_loss:.4f}  train_acc={tr_acc:.4f}  val_loss={val_loss:.4f}  val_acc={val_acc:.4f}")

        if val_loss < best_val:
            best_val, patience = val_loss, 0
            torch.save(model.state_dict(), f"../res/best_model_fold{fold_id}.pth")
        else:
            patience += 1
            if patience >= early_stopping_patience:
                print("Early stopping.")
                break

    # 測試
    model.load_state_dict(torch.load(f"../res/best_model_fold{fold_id}.pth", map_location=device))
    acc, bypass_rate, mal_n = test_metrics(model, test_loader, device)
    print(f"Fold {fold_id} → TestAcc={acc:.4f}, BypassRate(on label=1)={bypass_rate:.2%}, MaliciousInTest={mal_n}")

    results.append({"fold": fold_id, "test_acc": acc, "bypass_rate": bypass_rate, "malicious_in_test": mal_n})
    torch.cuda.empty_cache()
    fold_id += 1
# Out:
# ========== Fold 1/5 ==========
# Fold 1 | Epoch 001  train_loss=0.1218  train_acc=0.9537  val_loss=0.0724  val_acc=0.9769
# Fold 1 | Epoch 002  train_loss=0.0637  train_acc=0.9813  val_loss=0.0657  val_acc=0.9835
# Fold 1 | Epoch 003  train_loss=0.0590  train_acc=0.9827  val_loss=0.0613  val_acc=0.9835
# Fold 1 | Epoch 004  train_loss=0.0557  train_acc=0.9834  val_loss=0.0601  val_acc=0.9824
# Fold 1 | Epoch 005  train_loss=0.0549  train_acc=0.9832  val_loss=0.0624  val_acc=0.9835
# Fold 1 | Epoch 006  train_loss=0.0527  train_acc=0.9843  val_loss=0.0595  val_acc=0.9835
# Fold 1 | Epoch 007  train_loss=0.0533  train_acc=0.9838  val_loss=0.0566  val_acc=0.9835
# Fold 1 | Epoch 008  train_loss=0.0516  train_acc=0.9841  val_loss=0.0600  val_acc=0.9824
# Fold 1 | Epoch 009  train_loss=0.0509  train_acc=0.9849  val_loss=0.0561  val_acc=0.9824
# Fold 1 | Epoch 010  train_loss=0.0523  train_acc=0.9847  val_loss=0.0535  val_acc=0.9824
# Fold 1 | Epoch 011  train_loss=0.0496  train_acc=0.9842  val_loss=0.0608  val_acc=0.9824
# Fold 1 | Epoch 012  train_loss=0.0484  train_acc=0.9848  val_loss=0.0579  val_acc=0.9813
# Fold 1 | Epoch 013  train_loss=0.0492  train_acc=0.9846  val_loss=0.0563  val_acc=0.9824
# Fold 1 | Epoch 014  train_loss=0.0478  train_acc=0.9851  val_loss=0.0505  val_acc=0.9835
# Fold 1 | Epoch 015  train_loss=0.0488  train_acc=0.9843  val_loss=0.0562  val_acc=0.9835
# Fold 1 | Epoch 016  train_loss=0.0483  train_acc=0.9845  val_loss=0.0520  val_acc=0.9835
# Fold 1 | Epoch 017  train_loss=0.0464  train_acc=0.9851  val_loss=0.0513  val_acc=0.9835
# Fold 1 | Epoch 018  train_loss=0.0470  train_acc=0.9852  val_loss=0.0546  val_acc=0.9835
# Fold 1 | Epoch 019  train_loss=0.0471  train_acc=0.9851  val_loss=0.0561  val_acc=0.9835
# Fold 1 | Epoch 020  train_loss=0.0463  train_acc=0.9848  val_loss=0.0508  val_acc=0.9835
# Fold 1 | Epoch 021  train_loss=0.0463  train_acc=0.9856  val_loss=0.0495  val_acc=0.9824
# Fold 1 | Epoch 022  train_loss=0.0446  train_acc=0.9856  val_loss=0.0500  val_acc=0.9835
# Fold 1 | Epoch 023  train_loss=0.0444  train_acc=0.9854  val_loss=0.0506  val_acc=0.9824
# Fold 1 | Epoch 024  train_loss=0.0439  train_acc=0.9857  val_loss=0.0483  val_acc=0.9835
# Fold 1 | Epoch 025  train_loss=0.0450  train_acc=0.9853  val_loss=0.0491  val_acc=0.9824
# Fold 1 | Epoch 026  train_loss=0.0443  train_acc=0.9851  val_loss=0.0512  val_acc=0.9824
# Fold 1 | Epoch 027  train_loss=0.0436  train_acc=0.9858  val_loss=0.0517  val_acc=0.9824
# Fold 1 | Epoch 028  train_loss=0.0435  train_acc=0.9858  val_loss=0.0524  val_acc=0.9824
# Fold 1 | Epoch 029  train_loss=0.0441  train_acc=0.9857  val_loss=0.0529  val_acc=0.9835
# Fold 1 | Epoch 030  train_loss=0.0440  train_acc=0.9857  val_loss=0.0521  val_acc=0.9824
# Fold 1 | Epoch 031  train_loss=0.0429  train_acc=0.9859  val_loss=0.0492  val_acc=0.9824
# Fold 1 | Epoch 032  train_loss=0.0430  train_acc=0.9859  val_loss=0.0529  val_acc=0.9824
# Fold 1 | Epoch 033  train_loss=0.0434  train_acc=0.9856  val_loss=0.0491  val_acc=0.9824
# Fold 1 | Epoch 034  train_loss=0.0431  train_acc=0.9859  val_loss=0.0497  val_acc=0.9824
# Early stopping.
# Fold 1 → TestAcc=0.9868, BypassRate(on label=1)=1.52%, MaliciousInTest=1509
#
# ========== Fold 2/5 ==========
# Fold 2 | Epoch 001  train_loss=0.1082  train_acc=0.9556  val_loss=0.1159  val_acc=0.9604
# Fold 2 | Epoch 002  train_loss=0.0583  train_acc=0.9815  val_loss=0.0843  val_acc=0.9791
# Fold 2 | Epoch 003  train_loss=0.0547  train_acc=0.9845  val_loss=0.0928  val_acc=0.9725
# Fold 2 | Epoch 004  train_loss=0.0530  train_acc=0.9848  val_loss=0.0761  val_acc=0.9791
# Fold 2 | Epoch 005  train_loss=0.0518  train_acc=0.9853  val_loss=0.0772  val_acc=0.9791
# Fold 2 | Epoch 006  train_loss=0.0511  train_acc=0.9851  val_loss=0.0682  val_acc=0.9791
# Fold 2 | Epoch 007  train_loss=0.0495  train_acc=0.9857  val_loss=0.0770  val_acc=0.9791
# Fold 2 | Epoch 008  train_loss=0.0485  train_acc=0.9859  val_loss=0.0710  val_acc=0.9791
# Fold 2 | Epoch 009  train_loss=0.0486  train_acc=0.9853  val_loss=0.0666  val_acc=0.9780
# Fold 2 | Epoch 010  train_loss=0.0491  train_acc=0.9853  val_loss=0.0668  val_acc=0.9791
# Fold 2 | Epoch 011  train_loss=0.0466  train_acc=0.9856  val_loss=0.0619  val_acc=0.9791
# Fold 2 | Epoch 012  train_loss=0.0453  train_acc=0.9864  val_loss=0.0698  val_acc=0.9813
# Fold 2 | Epoch 013  train_loss=0.0455  train_acc=0.9862  val_loss=0.0685  val_acc=0.9802
# Fold 2 | Epoch 014  train_loss=0.0443  train_acc=0.9859  val_loss=0.0848  val_acc=0.9791
# Fold 2 | Epoch 015  train_loss=0.0432  train_acc=0.9863  val_loss=0.0702  val_acc=0.9791
# Fold 2 | Epoch 016  train_loss=0.0450  train_acc=0.9859  val_loss=0.0675  val_acc=0.9813
# Fold 2 | Epoch 017  train_loss=0.0448  train_acc=0.9860  val_loss=0.0680  val_acc=0.9802
# Fold 2 | Epoch 018  train_loss=0.0425  train_acc=0.9864  val_loss=0.0692  val_acc=0.9802
# Fold 2 | Epoch 019  train_loss=0.0415  train_acc=0.9863  val_loss=0.0732  val_acc=0.9813
# Fold 2 | Epoch 020  train_loss=0.0424  train_acc=0.9869  val_loss=0.0682  val_acc=0.9791
# Fold 2 | Epoch 021  train_loss=0.0423  train_acc=0.9867  val_loss=0.0693  val_acc=0.9791
# Early stopping.
# Fold 2 → TestAcc=0.9833, BypassRate(on label=1)=1.59%, MaliciousInTest=1508
#
# ========== Fold 3/5 ==========
# Fold 3 | Epoch 001  train_loss=0.1135  train_acc=0.9514  val_loss=0.0774  val_acc=0.9758
# Fold 3 | Epoch 002  train_loss=0.0626  train_acc=0.9819  val_loss=0.0833  val_acc=0.9736
# Fold 3 | Epoch 003  train_loss=0.0576  train_acc=0.9837  val_loss=0.0678  val_acc=0.9780
# Fold 3 | Epoch 004  train_loss=0.0548  train_acc=0.9846  val_loss=0.0738  val_acc=0.9791
# Fold 3 | Epoch 005  train_loss=0.0547  train_acc=0.9841  val_loss=0.0697  val_acc=0.9791
# Fold 3 | Epoch 006  train_loss=0.0525  train_acc=0.9850  val_loss=0.0885  val_acc=0.9747
# Fold 3 | Epoch 007  train_loss=0.0520  train_acc=0.9850  val_loss=0.0678  val_acc=0.9791
# Fold 3 | Epoch 008  train_loss=0.0503  train_acc=0.9852  val_loss=0.0708  val_acc=0.9791
# Fold 3 | Epoch 009  train_loss=0.0498  train_acc=0.9852  val_loss=0.0711  val_acc=0.9791
# Fold 3 | Epoch 010  train_loss=0.0475  train_acc=0.9858  val_loss=0.0692  val_acc=0.9802
# Fold 3 | Epoch 011  train_loss=0.0461  train_acc=0.9857  val_loss=0.0675  val_acc=0.9791
# Fold 3 | Epoch 012  train_loss=0.0474  train_acc=0.9854  val_loss=0.0683  val_acc=0.9802
# Fold 3 | Epoch 013  train_loss=0.0446  train_acc=0.9857  val_loss=0.0687  val_acc=0.9802
# Fold 3 | Epoch 014  train_loss=0.0462  train_acc=0.9856  val_loss=0.0728  val_acc=0.9802
# Fold 3 | Epoch 015  train_loss=0.0455  train_acc=0.9859  val_loss=0.0694  val_acc=0.9802
# Fold 3 | Epoch 016  train_loss=0.0454  train_acc=0.9859  val_loss=0.0750  val_acc=0.9791
# Fold 3 | Epoch 017  train_loss=0.0450  train_acc=0.9863  val_loss=0.0718  val_acc=0.9802
# Fold 3 | Epoch 018  train_loss=0.0438  train_acc=0.9861  val_loss=0.0729  val_acc=0.9802
# Fold 3 | Epoch 019  train_loss=0.0425  train_acc=0.9864  val_loss=0.0755  val_acc=0.9791
# Fold 3 | Epoch 020  train_loss=0.0435  train_acc=0.9859  val_loss=0.0768  val_acc=0.9802
# Fold 3 | Epoch 021  train_loss=0.0426  train_acc=0.9863  val_loss=0.0765  val_acc=0.9791
# Early stopping.
# Fold 3 → TestAcc=0.9837, BypassRate(on label=1)=1.92%, MaliciousInTest=1508
#
# ========== Fold 4/5 ==========
# Fold 4 | Epoch 001  train_loss=0.1301  train_acc=0.9478  val_loss=0.0856  val_acc=0.9692
# Fold 4 | Epoch 002  train_loss=0.0639  train_acc=0.9813  val_loss=0.0736  val_acc=0.9758
# Fold 4 | Epoch 003  train_loss=0.0579  train_acc=0.9836  val_loss=0.0786  val_acc=0.9769
# Fold 4 | Epoch 004  train_loss=0.0552  train_acc=0.9830  val_loss=0.0730  val_acc=0.9747
# Fold 4 | Epoch 005  train_loss=0.0525  train_acc=0.9851  val_loss=0.0893  val_acc=0.9758
# Fold 4 | Epoch 006  train_loss=0.0532  train_acc=0.9853  val_loss=0.0748  val_acc=0.9758
# Fold 4 | Epoch 007  train_loss=0.0489  train_acc=0.9847  val_loss=0.0667  val_acc=0.9769
# Fold 4 | Epoch 008  train_loss=0.0480  train_acc=0.9857  val_loss=0.0712  val_acc=0.9780
# Fold 4 | Epoch 009  train_loss=0.0487  train_acc=0.9856  val_loss=0.0792  val_acc=0.9769
# Fold 4 | Epoch 010  train_loss=0.0479  train_acc=0.9852  val_loss=0.0657  val_acc=0.9780
# Fold 4 | Epoch 011  train_loss=0.0480  train_acc=0.9852  val_loss=0.0676  val_acc=0.9758
# Fold 4 | Epoch 012  train_loss=0.0465  train_acc=0.9856  val_loss=0.0650  val_acc=0.9758
# Fold 4 | Epoch 013  train_loss=0.0451  train_acc=0.9865  val_loss=0.0692  val_acc=0.9780
# Fold 4 | Epoch 014  train_loss=0.0458  train_acc=0.9862  val_loss=0.0636  val_acc=0.9780
# Fold 4 | Epoch 015  train_loss=0.0441  train_acc=0.9864  val_loss=0.0656  val_acc=0.9758
# Fold 4 | Epoch 016  train_loss=0.0432  train_acc=0.9868  val_loss=0.0713  val_acc=0.9747
# Fold 4 | Epoch 017  train_loss=0.0450  train_acc=0.9863  val_loss=0.0649  val_acc=0.9769
# Fold 4 | Epoch 018  train_loss=0.0433  train_acc=0.9862  val_loss=0.0657  val_acc=0.9780
# Fold 4 | Epoch 019  train_loss=0.0431  train_acc=0.9864  val_loss=0.0806  val_acc=0.9780
# Fold 4 | Epoch 020  train_loss=0.0450  train_acc=0.9858  val_loss=0.0640  val_acc=0.9769
# Fold 4 | Epoch 021  train_loss=0.0414  train_acc=0.9867  val_loss=0.0621  val_acc=0.9780
# Fold 4 | Epoch 022  train_loss=0.0407  train_acc=0.9873  val_loss=0.0668  val_acc=0.9769
# Fold 4 | Epoch 023  train_loss=0.0411  train_acc=0.9872  val_loss=0.0618  val_acc=0.9780
# Fold 4 | Epoch 024  train_loss=0.0410  train_acc=0.9869  val_loss=0.0660  val_acc=0.9758
# Fold 4 | Epoch 025  train_loss=0.0439  train_acc=0.9868  val_loss=0.0650  val_acc=0.9769
# Fold 4 | Epoch 026  train_loss=0.0414  train_acc=0.9873  val_loss=0.0614  val_acc=0.9780
# Fold 4 | Epoch 027  train_loss=0.0405  train_acc=0.9867  val_loss=0.0662  val_acc=0.9769
# Fold 4 | Epoch 028  train_loss=0.0418  train_acc=0.9865  val_loss=0.0636  val_acc=0.9769
# Fold 4 | Epoch 029  train_loss=0.0424  train_acc=0.9865  val_loss=0.0616  val_acc=0.9780
# Fold 4 | Epoch 030  train_loss=0.0399  train_acc=0.9872  val_loss=0.0616  val_acc=0.9780
# Fold 4 | Epoch 031  train_loss=0.0406  train_acc=0.9873  val_loss=0.0625  val_acc=0.9780
# Fold 4 | Epoch 032  train_loss=0.0406  train_acc=0.9870  val_loss=0.0604  val_acc=0.9780
# Fold 4 | Epoch 033  train_loss=0.0391  train_acc=0.9872  val_loss=0.0631  val_acc=0.9780
# Fold 4 | Epoch 034  train_loss=0.0407  train_acc=0.9868  val_loss=0.0645  val_acc=0.9780
# Fold 4 | Epoch 035  train_loss=0.0410  train_acc=0.9875  val_loss=0.0609  val_acc=0.9780
# Fold 4 | Epoch 036  train_loss=0.0405  train_acc=0.9867  val_loss=0.0609  val_acc=0.9780
# Fold 4 | Epoch 037  train_loss=0.0401  train_acc=0.9875  val_loss=0.0619  val_acc=0.9780
# Fold 4 | Epoch 038  train_loss=0.0395  train_acc=0.9865  val_loss=0.0621  val_acc=0.9780
# Fold 4 | Epoch 039  train_loss=0.0391  train_acc=0.9875  val_loss=0.0611  val_acc=0.9780
# Fold 4 | Epoch 040  train_loss=0.0391  train_acc=0.9874  val_loss=0.0628  val_acc=0.9780
# Fold 4 | Epoch 041  train_loss=0.0385  train_acc=0.9874  val_loss=0.0620  val_acc=0.9780
# Fold 4 | Epoch 042  train_loss=0.0384  train_acc=0.9874  val_loss=0.0635  val_acc=0.9780
# Early stopping.
# Fold 4 → TestAcc=0.9837, BypassRate(on label=1)=1.86%, MaliciousInTest=1508
#
# ========== Fold 5/5 ==========
# Fold 5 | Epoch 001  train_loss=0.1217  train_acc=0.9557  val_loss=0.0729  val_acc=0.9769
# Fold 5 | Epoch 002  train_loss=0.0633  train_acc=0.9804  val_loss=0.0614  val_acc=0.9813
# Fold 5 | Epoch 003  train_loss=0.0557  train_acc=0.9838  val_loss=0.0510  val_acc=0.9868
# Fold 5 | Epoch 004  train_loss=0.0541  train_acc=0.9840  val_loss=0.0508  val_acc=0.9868
# Fold 5 | Epoch 005  train_loss=0.0520  train_acc=0.9848  val_loss=0.0478  val_acc=0.9868
# Fold 5 | Epoch 006  train_loss=0.0514  train_acc=0.9842  val_loss=0.0496  val_acc=0.9868
# Fold 5 | Epoch 007  train_loss=0.0484  train_acc=0.9847  val_loss=0.0503  val_acc=0.9868
# Fold 5 | Epoch 008  train_loss=0.0496  train_acc=0.9842  val_loss=0.0486  val_acc=0.9868
# Fold 5 | Epoch 009  train_loss=0.0478  train_acc=0.9850  val_loss=0.0535  val_acc=0.9846
# Fold 5 | Epoch 010  train_loss=0.0484  train_acc=0.9857  val_loss=0.0533  val_acc=0.9868
# Fold 5 | Epoch 011  train_loss=0.0490  train_acc=0.9846  val_loss=0.0529  val_acc=0.9868
# Fold 5 | Epoch 012  train_loss=0.0457  train_acc=0.9852  val_loss=0.0517  val_acc=0.9868
# Fold 5 | Epoch 013  train_loss=0.0462  train_acc=0.9852  val_loss=0.0509  val_acc=0.9868
# Fold 5 | Epoch 014  train_loss=0.0464  train_acc=0.9853  val_loss=0.0522  val_acc=0.9868
# Fold 5 | Epoch 015  train_loss=0.0464  train_acc=0.9852  val_loss=0.0522  val_acc=0.9868
# Early stopping.
# Fold 5 → TestAcc=0.9828, BypassRate(on label=1)=1.79%, MaliciousInTest=1508

# %%
# 彙總與輸出
import pandas as pd, numpy as np

df_res = pd.DataFrame(results)
display(df_res)
print("\nAverages (ignore NaN):")
display(df_res.mean(numeric_only=True))

df_res.to_csv("../res/cv5_metrics.csv", index=False)
# Out:
#    fold  test_acc  bypass_rate  malicious_in_test
# 0     1  0.986790     0.015242               1509
# 1     2  0.983267     0.015915               1508
# 2     3  0.983700     0.019231               1508
# 3     4  0.983700     0.018568               1508
# 4     5  0.982819     0.017905               1508
# Averages (ignore NaN):
# fold                    3.000000
# test_acc                0.984056
# bypass_rate             0.017372
# malicious_in_test    1508.200000
# dtype: float64
